# %% [markdown]
# # Feedforward Network using Tensorflow

# %%
# Package imports
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib

# Display plots inline and change default figure size
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# ## Generating a dataset
#
# Let's start by generating a dataset we can play with. Fortunately, [scikit-learn](http://scikit-learn.org/) has some useful dataset generators, so we don't need to write the code ourselves. We will go with the [`make_moons`](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html) function.

# %%
# Generate a dataset and plot it
np.random.seed(0)
Xt, yt = sklearn.datasets.make_moons(200, noise=0.20)
print(Xt.shape, yt.shape)
plt.scatter(Xt[:,0], Xt[:,1], s=40, c=yt, cmap=plt.cm.Spectral)
# Out:
# (200, 2) (200,)

# %%
import tensorflow as tf
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
RANDOM_SEED = 12
tf.set_random_seed(RANDOM_SEED)

# %%
def init_weights(shape):
    """ Weight initialization """
    weights = tf.random_normal(shape, stddev=0.1)
    return tf.Variable(weights)

def forwardprop(X, w_1, w_2):
    """
    Forward-propagation.
    IMPORTANT: yhat is not softmax since TensorFlow's softmax_cross_entropy_with_logits() does that internally.
    """
    h    = tf.nn.sigmoid(tf.matmul(X, w_1))  # The \sigma function
    yhat = tf.matmul(h, w_2)  # The \varphi function
    return yhat

# %%
y_t = np.array([[0,1] if i == 0 else [1,0] for i in yt])
train_X, test_X, train_y, test_y = Xt, Xt, y_t, y_t

# %%
def build_model(nn_hdim=256, epochs=20, print_loss=False):

    # Layer's sizes
    x_size = train_X.shape[1] 
    h_size = nn_hdim                # Number of hidden nodes
    y_size = 2   

    # Symbols
    X = tf.placeholder("float", shape=[None, x_size])
    y = tf.placeholder("float", shape=[None, y_size])

    # Weight initializations
    w_1 = init_weights((x_size, h_size))
    w_2 = init_weights((h_size, y_size))

    # Forward propagation
    yhat    = forwardprop(X, w_1, w_2)
    predict = tf.argmax(yhat, axis=1)

    # Backward propagation
    cost    = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=yhat))
    updates = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

    # Run SGD
    
    init = tf.global_variables_initializer()
    sess.run(init)

    for epoch in range(epochs):
        # Train with each example
        for i in range(len(train_X)):
            sess.run(updates, feed_dict={X: train_X[i: i + 1], y: train_y[i: i + 1]})

        train_accuracy = np.mean(np.argmax(train_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: train_X, y: train_y}))
        test_accuracy  = np.mean(np.argmax(test_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: test_X, y: test_y}))
        if print_loss:
            print("Epoch = %d, train accuracy = %.2f%%, test accuracy = %.2f%%"
                  % (epoch + 1, 100. * train_accuracy, 100. * test_accuracy))
    return test_accuracy

sess = tf.Session() # need to deal with sessions
build_model(3, 50,print_loss=True)
# Out:
# WARNING:tensorflow:From <ipython-input-7-effede97242b>:21: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# Epoch = 1, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 2, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 3, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 4, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 5, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 6, train accuracy = 62.00%, test accuracy = 62.00%
# Epoch = 7, train accuracy = 75.50%, test accuracy = 75.50%
# Epoch = 8, train accuracy = 79.50%, test accuracy = 79.50%
# Epoch = 9, train accuracy = 78.50%, test accuracy = 78.50%
# Epoch = 10, train accuracy = 77.50%, test accuracy = 77.50%
# Epoch = 11, train accuracy = 77.00%, test accuracy = 77.00%
# Epoch = 12, train accuracy = 77.50%, test accuracy = 77.50%
# Epoch = 13, train accuracy = 78.00%, test accuracy = 78.00%
# Epoch = 14, train accuracy = 78.00%, test accuracy = 78.00%
# Epoch = 15, train accuracy = 78.00%, test accuracy = 78.00%
# Epoch = 16, train accuracy = 79.00%, test accuracy = 79.00%
# Epoch = 17, train accuracy = 79.50%, test accuracy = 79.50%
# Epoch = 18, train accuracy = 79.50%, test accuracy = 79.50%
# Epoch = 19, train accuracy = 79.50%, test accuracy = 79.50%
# Epoch = 20, train accuracy = 80.50%, test accuracy = 80.50%
# Epoch = 21, train accuracy = 81.50%, test accuracy = 81.50%
# Epoch = 22, train accuracy = 81.50%, test accuracy = 81.50%
# Epoch = 23, train accuracy = 82.00%, test accuracy = 82.00%
# Epoch = 24, train accuracy = 82.50%, test accuracy = 82.50%
# Epoch = 25, train accuracy = 82.50%, test accuracy = 82.50%
# Epoch = 26, train accuracy = 82.50%, test accuracy = 82.50%
# Epoch = 27, train accuracy = 82.50%, test accuracy = 82.50%
# Epoch = 28, train accuracy = 82.50%, test accuracy = 82.50%
# Epoch = 29, train accuracy = 82.50%, test accuracy = 82.50%
# Epoch = 30, train accuracy = 82.50%, test accuracy = 82.50%
# Epoch = 31, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 32, train accuracy = 83.00%, test accuracy = 83.00%
# Epoch = 33, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 34, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 35, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 36, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 37, train accuracy = 84.00%, test accuracy = 84.00%
# Epoch = 38, train accuracy = 84.00%, test accuracy = 84.00%
# Epoch = 39, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 40, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 41, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 42, train accuracy = 83.50%, test accuracy = 83.50%
# Epoch = 43, train accuracy = 85.00%, test accuracy = 85.00%
# Epoch = 44, train accuracy = 85.00%, test accuracy = 85.00%
# Epoch = 45, train accuracy = 85.50%, test accuracy = 85.50%
# Epoch = 46, train accuracy = 85.50%, test accuracy = 85.50%
# Epoch = 47, train accuracy = 85.50%, test accuracy = 85.50%
# Epoch = 48, train accuracy = 85.50%, test accuracy = 85.50%
# Epoch = 49, train accuracy = 85.50%, test accuracy = 85.50%
# Epoch = 50, train accuracy = 85.50%, test accuracy = 85.50%
# 0.855

# %% [markdown]
# # Varying the hidden layer size
#
# In the example above we picked a hidden layer size of 3. Let's now get a sense of how varying the hidden layer size affects the result.

# %%
hidden_layer_dimensions = [1, 2, 3, 4, 5, 20, 50]
for i, nn_hdim in enumerate(hidden_layer_dimensions):
    sess = tf.Session()
    print(nn_hdim, build_model(nn_hdim,print_loss=False))
    sess.close()
plt.show()
# Out:
# 1 0.5
# 2 0.785
# 3 0.825
# 4 0.81
# 5 0.815
# 20 0.83
# 50 0.835

# %% [markdown]
# # Exercises
#
# Here are some things you can try to become more familiar with the code:
#
# 1. Instead of batch gradient descent, use minibatch gradient descent ([more info](http://cs231n.github.io/optimization-1/#gd)) to train the network. Minibatch gradient descent typically performs better in practice.
# 2. We used a fixed learning rate $\epsilon$ for gradient descent. Implement an annealing schedule for the gradient descent learning rate ([more info](http://cs231n.github.io/neural-networks-3/#anneal)).
# 3. We used a $\tanh$ activation function for our hidden layer. Experiment with other activation functions (some are mentioned above). Note that changing the activation function also means changing the backpropagation derivative.
# 4. Extend the network from two to three classes. You will need to generate an appropriate dataset for this.
# 5. Extend the network to four layers. Experiment with the layer size. Adding another hidden layer means you will need to adjust both the forward propagation as well as the backpropagation code.

# %% [markdown]
# # Since changing to ReLU was really easy (just change tf.nn.sigmoid to tf.nn.relu), I decided to add another layer to the network as well.

# %%
RANDOM_SEED = 12
tf.set_random_seed(RANDOM_SEED)

# %%
def init_weights(shape):
    """ Weight initialization """
    weights = tf.random_normal(shape, stddev=0.1)
    return tf.Variable(weights)

def forwardprop(X, w_1, w_2, w_3):
    """
    Forward-propagation.
    IMPORTANT: yhat is not softmax since TensorFlow's softmax_cross_entropy_with_logits() does that internally.
    """
    o1    = tf.nn.relu(tf.matmul(X, w_1))  # The relu function
    o2    = tf.nn.relu(tf.matmul(o1, w_2))
    yhat = tf.matmul(o2, w_3)  # The \varphi function
    return yhat

# %%
y_t = np.array([[0,1] if i == 0 else [1,0] for i in yt])
train_X, test_X, train_y, test_y = Xt, Xt, y_t, y_t

# %%
def build_model(nn_hdim=256, epochs=20, print_loss=False):

    # Layer's sizes
    x_size = train_X.shape[1] 
    h_size = nn_hdim                # Number of hidden nodes
    y_size = 2   

    # Symbols
    X = tf.placeholder("float", shape=[None, x_size])
    y = tf.placeholder("float", shape=[None, y_size])

    # Weight initializations
    w_1 = init_weights((x_size, h_size))
    w_2 = init_weights((h_size, h_size))
    w_3 = init_weights((h_size, y_size))

    # Forward propagation
    yhat    = forwardprop(X, w_1, w_2, w_3)
    predict = tf.argmax(yhat, axis=1)

    # Backward propagation
    cost    = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=yhat))
    updates = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

    # Run SGD
    
    init = tf.global_variables_initializer()
    sess.run(init)

    for epoch in range(epochs):
        # Train with each example
        for i in range(len(train_X)):
            sess.run(updates, feed_dict={X: train_X[i: i + 1], y: train_y[i: i + 1]})

        train_accuracy = np.mean(np.argmax(train_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: train_X, y: train_y}))
        test_accuracy  = np.mean(np.argmax(test_y, axis=1) ==
                                 sess.run(predict, feed_dict={X: test_X, y: test_y}))
        if print_loss:
            print("Epoch = %d, train accuracy = %.2f%%, test accuracy = %.2f%%"
                  % (epoch + 1, 100. * train_accuracy, 100. * test_accuracy))
    return test_accuracy

sess = tf.Session() # need to deal with sessions
build_model(3, 50,print_loss=True)
# Out:
# Epoch = 1, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 2, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 3, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 4, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 5, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 6, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 7, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 8, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 9, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 10, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 11, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 12, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 13, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 14, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 15, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 16, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 17, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 18, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 19, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 20, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 21, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 22, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 23, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 24, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 25, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 26, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 27, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 28, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 29, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 30, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 31, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 32, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 33, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 34, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 35, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 36, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 37, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 38, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 39, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 40, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 41, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 42, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 43, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 44, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 45, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 46, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 47, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 48, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 49, train accuracy = 50.00%, test accuracy = 50.00%
# Epoch = 50, train accuracy = 50.00%, test accuracy = 50.00%
# 0.5

# %%
hidden_layer_dimensions = [1, 2, 3, 4, 5, 20, 50]
for i, nn_hdim in enumerate(hidden_layer_dimensions):
    sess = tf.Session()
    print(nn_hdim, build_model(nn_hdim,print_loss=False))
    sess.close()
plt.show()
# Out:
# 1 0.5
# 2 0.5
# 3 0.83
# 4 0.8
# 5 0.855
# 20 0.845
# 50 0.845
